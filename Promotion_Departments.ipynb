# %% [markdown]
# In this notebook, we are trying to answer these questions:
# - Is it 'easier' to get promoted in certain departments?
# 	- Check promoted people’s training score vs. not promoted
# 	- Check awards and KPI
# 	- previous year rating
# 	- number of trainings
# 	- does education matter?
# 	- does recruitment channel matter?
# 	- Split up gender for each question

# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, plot_confusion_matrix, accuracy_score, f1_score

from google.colab import drive
drive.mount('/content/drive')
drive_dir = '/content/drive/My Drive/Project_3/'
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(drive_dir + 'data/promotion_train_data.csv')

# %% [markdown]
# #Cleaning Data

# %%
df.head()
# Out:
#    employee_id         department  ... avg_training_score is_promoted
# 0        65438  Sales & Marketing  ...                 49           0
# 1        65141         Operations  ...                 60           0
# 2         7513  Sales & Marketing  ...                 50           0
# 3         2542  Sales & Marketing  ...                 50           0
# 4        48945         Technology  ...                 73           0
#
# [5 rows x 14 columns]

# %%
df = df.drop('employee_id',axis = 1)

# %%
for col in df.columns:
  percent = 100 * df[col].isna().sum() / df.shape[0]
  percent = round(percent,2)
  print(f'{col}: {df[col].isna().sum()} ({percent}%) missing values')
# Out:
# department: 0 (0.0%) missing values
# region: 0 (0.0%) missing values
# education: 2409 (4.4%) missing values
# gender: 0 (0.0%) missing values
# recruitment_channel: 0 (0.0%) missing values
# no_of_trainings: 0 (0.0%) missing values
# age: 0 (0.0%) missing values
# previous_year_rating: 4124 (7.52%) missing values
# length_of_service: 0 (0.0%) missing values
# KPIs_met >80%: 0 (0.0%) missing values
# awards_won?: 0 (0.0%) missing values
# avg_training_score: 0 (0.0%) missing values
# is_promoted: 0 (0.0%) missing values

# %%
df['education'].unique()
# Out:
# array(["Master's & above", "Bachelor's", nan, 'Below Secondary'],
#       dtype=object)

# %%
#Replacing NaN instead of dropping b/c I want to keep those rows
df['education'] = df.education.fillna('Unknown')

# %%
df['previous_year_rating'].unique()
# Out:
# array([ 5.,  3.,  1.,  4., nan,  2.])

# %%
#Ratings are 1-5, so 0 will mean employee was not here last year
df['previous_year_rating'] = df.previous_year_rating.fillna(0)

# %%
df['starting_age'] = df['age']-df['length_of_service']

# %%
df['total_training_score'] = df['no_of_trainings']*df['avg_training_score']

# %%
df = df.rename(columns={'KPIs_met >80%': 'KPIs_met>80%'})

# %%
le = LabelEncoder()
class_col = ['department', 'region', 'education', 'recruitment_channel']
for col in class_col:
  le.fit(df[col])
  df[f'{col}_num'] = le.transform(df[col])

# %%
#based off of percentages of promotion. Lowered older than 40 with 0 rating bc only 11 people
def age_rating(row):
  if row['age'] <= 40 and row['previous_year_rating'] == 0:
    return 10
  elif row['age'] <= 40 and row['previous_year_rating'] == 1:
    return 2
  elif row['age'] <= 40 and row['previous_year_rating'] == 2:
    return 4
  elif row['age'] <= 40 and row['previous_year_rating'] == 3:
    return 7
  elif row['age'] <= 40 and row['previous_year_rating'] == 4:
    return 9
  elif row['age'] <= 40 and row['previous_year_rating'] == 5:
    return 12
  elif row['age'] > 40 and row['previous_year_rating'] == 0:
    return 6
  elif row['age'] > 40 and row['previous_year_rating'] == 1:
    return 1
  elif row['age'] > 40 and row['previous_year_rating'] == 2:
    return 3
  elif row['age'] > 40 and row['previous_year_rating'] == 3:
    return 5
  elif row['age'] > 40 and row['previous_year_rating'] == 4:
    return 8
  else:
    return 11

# %%
def age_KPI(row):
  if row['age'] <= 45 and row['KPIs_met>80%'] == 0:
    return 2
  elif row['age'] <= 45 and row['KPIs_met>80%'] == 1:
    return 4
  elif row['age'] > 45 and row['KPIs_met>80%'] == 0:
    return 3
  else:
    return 1

# %%
df['age_rating'] = df.apply(age_rating, axis=1)

# %%
df['age_KPI'] = df.apply(age_KPI, axis=1)

# %%
df.dtypes
# Out:
# department                  object
# region                      object
# education                   object
# gender                      object
# recruitment_channel         object
# no_of_trainings              int64
# age                          int64
# previous_year_rating       float64
# length_of_service            int64
# KPIs_met>80%                 int64
# awards_won?                  int64
# avg_training_score           int64
# is_promoted                  int64
# starting_age                 int64
# total_training_score         int64
# department_num               int64
# region_num                   int64
# education_num                int64
# recruitment_channel_num      int64
# age_rating                   int64
# age_KPI                      int64
# dtype: object

# %%
df.isna().sum()
# Out:
# department                 0
# region                     0
# education                  0
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating       0
# length_of_service          0
# KPIs_met>80%               0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# starting_age               0
# total_training_score       0
# department_num             0
# region_num                 0
# education_num              0
# recruitment_channel_num    0
# age_rating                 0
# age_KPI                    0
# dtype: int64

# %%
df.head()
# Out:
#           department     region  ... age_rating age_KPI
# 0  Sales & Marketing   region_7  ...         12       4
# 1         Operations  region_22  ...         12       2
# 2  Sales & Marketing  region_19  ...          7       2
# 3  Sales & Marketing  region_23  ...          2       2
# 4         Technology  region_26  ...          5       2
#
# [5 rows x 21 columns]

# %%
male_df = df[df['gender'] == 'm']
female_df = df[df['gender'] == 'f']

# %%
met_KPI_male_df = male_df[male_df['KPIs_met>80%'] == 1]
no_met_KPI_male_df = male_df[male_df['KPIs_met>80%'] != 1]
met_KPI_female_df = female_df[female_df['KPIs_met>80%'] == 1]
no_met_KPI_female_df = female_df[female_df['KPIs_met>80%'] != 1]

# %% [markdown]
# #Looking for general facts

# %%
#Rating 0 means they were not there last year
#What do these 8% of people do to get promoted?
for i in df['previous_year_rating'].unique():
  rating_df = df[df['previous_year_rating'] == i]
  total = rating_df.shape[0]
  promoted = rating_df[rating_df['is_promoted'] == 1].shape[0]
  percent = 100*promoted/total
  print(f"Employee's with previous year rating {i} were promoted {percent: .2f}% of the time. ({promoted} out of {total})")
# Out:
# Employee's with previous year rating 5.0 were promoted  16.36% of the time. (1921 out of 11741)
# Employee's with previous year rating 3.0 were promoted  7.28% of the time. (1355 out of 18618)
# Employee's with previous year rating 1.0 were promoted  1.41% of the time. (88 out of 6223)
# Employee's with previous year rating 4.0 were promoted  7.94% of the time. (784 out of 9877)
# Employee's with previous year rating 0.0 were promoted  8.22% of the time. (339 out of 4124)
# Employee's with previous year rating 2.0 were promoted  4.28% of the time. (181 out of 4225)

# %%
zero_df = df[df['previous_year_rating'] == 0]

# %%
#Looks like average training score is an important factor for promotions
#0 is not promoted
#1 is promoted
for i, group in zero_df.groupby('is_promoted'):
  training_score_mean = group['avg_training_score'].mean()
  print(f"The average training score for {i} with a 0 previous year rating was {training_score_mean}")

for i, group in df.groupby('is_promoted'):
  training_score_mean = group['avg_training_score'].mean()
  print(f"The average training score for all people for {i} rating was {training_score_mean}")
# Out:
# The average training score for 0 with a 0 previous year rating was 62.589696169088505
# The average training score for 1 with a 0 previous year rating was 71.929203539823
# The average training score for all people for 0 rating was 62.64768647786199
# The average training score for all people for 1 rating was 71.32519280205655

# %% [markdown]
# #Here we are looking to answer:
# - Is it 'easier' to get promoted in certain departments?

# %%
#Percent of people to get promoted in each category
def promo_by_group(col):
  for i,group in df.groupby(col):
    total = group.shape[0]
    promoted = group[group['is_promoted'] == 1].shape[0]
    percent = 100*promoted/total
    print(f"{i}: promoted {percent:.2f}% of the time. ({promoted} out of {total})")

# %%
#Percent of people to get promoted in each category by gender
def promo_by_group_gender(col):
  for i,group in df.groupby(col):
    male_df = group[group['gender'] == 'm']
    female_df = group[group['gender'] == 'f']
    total_male = male_df.shape[0]
    total_female = female_df.shape[0]
    promoted_male = male_df[male_df['is_promoted'] == 1].shape[0]
    promoted_female = female_df[female_df['is_promoted'] == 1].shape[0]
    if total_male == 0:
      print('There are no males in this category')
      return None
    if total_female == 0:
      print('There are no females in this category')
      return None
    percent_male = 100*promoted_male/total_male
    percent_female = 100*promoted_female/total_female
    print(f"{i} Males:  were promoted {percent_male:.2f}% of the time. ({promoted_male} out of {total_male})")
    print(f"{i} Females: department were promoted {percent_female:.2f}% of the time. ({promoted_female} out of {total_female})")
    print('='*100)

# %%
category = ['department', 'region', 'education', 'gender', 'recruitment_channel',
       'no_of_trainings','age', 'previous_year_rating', 'length_of_service',
       'KPIs_met>80%', 'awards_won?']

for col in category:
  print(col.upper(), ':')
  print(promo_by_group(col))
  print("="*100)
# Out:
# DEPARTMENT :
# Analytics: promoted 9.57% of the time. (512 out of 5352)
# Finance: promoted 8.12% of the time. (206 out of 2536)
# HR: promoted 5.62% of the time. (136 out of 2418)
# Legal: promoted 5.10% of the time. (53 out of 1039)
# Operations: promoted 9.01% of the time. (1023 out of 11348)
# Procurement: promoted 9.64% of the time. (688 out of 7138)
# R&D: promoted 6.91% of the time. (69 out of 999)
# Sales & Marketing: promoted 7.20% of the time. (1213 out of 16840)
# Technology: promoted 10.76% of the time. (768 out of 7138)
# None
# ====================================================================================================
# REGION :
# region_1: promoted 9.51% of the time. (58 out of 610)
# region_10: promoted 7.87% of the time. (51 out of 648)
# region_11: promoted 5.63% of the time. (74 out of 1315)
# region_12: promoted 6.60% of the time. (33 out of 500)
# region_13: promoted 8.69% of the time. (230 out of 2648)
# region_14: promoted 7.50% of the time. (62 out of 827)
# region_15: promoted 7.91% of the time. (222 out of 2808)
# region_16: promoted 6.96% of the time. (102 out of 1465)
# region_17: promoted 13.69% of the time. (109 out of 796)
# region_18: promoted 3.23% of the time. (1 out of 31)
# region_19: promoted 6.06% of the time. (53 out of 874)
# region_2: promoted 8.01% of the time. (989 out of 12343)
# region_20: promoted 5.76% of the time. (49 out of 850)
# region_21: promoted 4.38% of the time. (18 out of 411)
# region_22: promoted 11.42% of the time. (734 out of 6428)
# region_23: promoted 11.66% of the time. (137 out of 1175)
# region_24: promoted 3.54% of the time. (18 out of 508)
# region_25: promoted 12.58% of the time. (103 out of 819)
# region_26: promoted 6.33% of the time. (143 out of 2260)
# region_27: promoted 7.90% of the time. (131 out of 1659)
# region_28: promoted 11.68% of the time. (154 out of 1318)
# region_29: promoted 4.33% of the time. (43 out of 994)
# region_3: promoted 10.69% of the time. (37 out of 346)
# region_30: promoted 8.98% of the time. (59 out of 657)
# region_31: promoted 5.68% of the time. (110 out of 1935)
# region_32: promoted 4.23% of the time. (40 out of 945)
# region_33: promoted 3.72% of the time. (10 out of 269)
# region_34: promoted 2.74% of the time. (8 out of 292)
# region_4: promoted 14.45% of the time. (246 out of 1703)
# region_5: promoted 4.57% of the time. (35 out of 766)
# region_6: promoted 4.64% of the time. (32 out of 690)
# region_7: promoted 10.65% of the time. (516 out of 4843)
# region_8: promoted 8.09% of the time. (53 out of 655)
# region_9: promoted 1.90% of the time. (8 out of 420)
# None
# ====================================================================================================
# EDUCATION :
# Bachelor's: promoted 8.20% of the time. (3008 out of 36669)
# Below Secondary: promoted 8.32% of the time. (67 out of 805)
# Master's & above: promoted 9.86% of the time. (1471 out of 14925)
# Unknown: promoted 5.06% of the time. (122 out of 2409)
# None
# ====================================================================================================
# GENDER :
# f: promoted 8.99% of the time. (1467 out of 16312)
# m: promoted 8.32% of the time. (3201 out of 38496)
# None
# ====================================================================================================
# RECRUITMENT_CHANNEL :
# other: promoted 8.40% of the time. (2556 out of 30446)
# referred: promoted 12.08% of the time. (138 out of 1142)
# sourcing: promoted 8.50% of the time. (1974 out of 23220)
# None
# ====================================================================================================
# NO_OF_TRAININGS :
# 1: promoted 8.81% of the time. (3910 out of 44378)
# 2: promoted 7.57% of the time. (605 out of 7987)
# 3: promoted 6.87% of the time. (122 out of 1776)
# 4: promoted 5.56% of the time. (26 out of 468)
# 5: promoted 2.34% of the time. (3 out of 128)
# 6: promoted 4.55% of the time. (2 out of 44)
# 7: promoted 0.00% of the time. (0 out of 12)
# 8: promoted 0.00% of the time. (0 out of 5)
# 9: promoted 0.00% of the time. (0 out of 5)
# 10: promoted 0.00% of the time. (0 out of 5)
# None
# ====================================================================================================
# AGE :
# 20: promoted 3.54% of the time. (4 out of 113)
# 21: promoted 5.10% of the time. (5 out of 98)
# 22: promoted 7.79% of the time. (18 out of 231)
# 23: promoted 7.94% of the time. (34 out of 428)
# 24: promoted 8.28% of the time. (70 out of 845)
# 25: promoted 5.31% of the time. (69 out of 1299)
# 26: promoted 7.91% of the time. (163 out of 2060)
# 27: promoted 9.23% of the time. (261 out of 2827)
# 28: promoted 9.79% of the time. (308 out of 3147)
# 29: promoted 8.63% of the time. (294 out of 3405)
# 30: promoted 8.84% of the time. (324 out of 3665)
# 31: promoted 8.77% of the time. (310 out of 3534)
# 32: promoted 8.40% of the time. (297 out of 3534)
# 33: promoted 9.94% of the time. (319 out of 3210)
# 34: promoted 9.30% of the time. (286 out of 3076)
# 35: promoted 10.44% of the time. (283 out of 2711)
# 36: promoted 8.26% of the time. (208 out of 2517)
# 37: promoted 8.50% of the time. (184 out of 2165)
# 38: promoted 9.57% of the time. (184 out of 1923)
# 39: promoted 9.50% of the time. (161 out of 1695)
# 40: promoted 7.64% of the time. (127 out of 1663)
# 41: promoted 8.07% of the time. (104 out of 1289)
# 42: promoted 7.92% of the time. (91 out of 1149)
# 43: promoted 7.76% of the time. (77 out of 992)
# 44: promoted 8.26% of the time. (70 out of 847)
# 45: promoted 6.32% of the time. (48 out of 760)
# 46: promoted 6.17% of the time. (43 out of 697)
# 47: promoted 4.85% of the time. (27 out of 557)
# 48: promoted 7.90% of the time. (44 out of 557)
# 49: promoted 7.48% of the time. (33 out of 441)
# 50: promoted 5.95% of the time. (31 out of 521)
# 51: promoted 8.74% of the time. (34 out of 389)
# 52: promoted 7.98% of the time. (28 out of 351)
# 53: promoted 3.85% of the time. (14 out of 364)
# 54: promoted 7.67% of the time. (24 out of 313)
# 55: promoted 6.12% of the time. (18 out of 294)
# 56: promoted 7.95% of the time. (21 out of 264)
# 57: promoted 2.10% of the time. (5 out of 238)
# 58: promoted 7.51% of the time. (16 out of 213)
# 59: promoted 8.13% of the time. (17 out of 209)
# 60: promoted 6.45% of the time. (14 out of 217)
# None
# ====================================================================================================
# PREVIOUS_YEAR_RATING :
# 0.0: promoted 8.22% of the time. (339 out of 4124)
# 1.0: promoted 1.41% of the time. (88 out of 6223)
# 2.0: promoted 4.28% of the time. (181 out of 4225)
# 3.0: promoted 7.28% of the time. (1355 out of 18618)
# 4.0: promoted 7.94% of the time. (784 out of 9877)
# 5.0: promoted 16.36% of the time. (1921 out of 11741)
# None
# ====================================================================================================
# LENGTH_OF_SERVICE :
# 1: promoted 8.29% of the time. (377 out of 4547)
# 2: promoted 8.90% of the time. (595 out of 6684)
# 3: promoted 8.66% of the time. (609 out of 7033)
# 4: promoted 8.75% of the time. (598 out of 6836)
# 5: promoted 8.14% of the time. (475 out of 5832)
# 6: promoted 8.47% of the time. (401 out of 4734)
# 7: promoted 8.36% of the time. (464 out of 5551)
# 8: promoted 9.33% of the time. (269 out of 2883)
# 9: promoted 8.71% of the time. (229 out of 2629)
# 10: promoted 9.30% of the time. (204 out of 2193)
# 11: promoted 10.48% of the time. (96 out of 916)
# 12: promoted 7.93% of the time. (63 out of 794)
# 13: promoted 7.86% of the time. (54 out of 687)
# 14: promoted 5.28% of the time. (29 out of 549)
# 15: promoted 7.25% of the time. (43 out of 593)
# 16: promoted 7.48% of the time. (41 out of 548)
# 17: promoted 6.02% of the time. (26 out of 432)
# 18: promoted 6.38% of the time. (25 out of 392)
# 19: promoted 9.73% of the time. (32 out of 329)
# 20: promoted 7.81% of the time. (10 out of 128)
# 21: promoted 5.13% of the time. (4 out of 78)
# 22: promoted 9.84% of the time. (6 out of 61)
# 23: promoted 10.77% of the time. (7 out of 65)
# 24: promoted 0.00% of the time. (0 out of 70)
# 25: promoted 3.92% of the time. (2 out of 51)
# 26: promoted 0.00% of the time. (0 out of 41)
# 27: promoted 2.78% of the time. (1 out of 36)
# 28: promoted 6.67% of the time. (2 out of 30)
# 29: promoted 10.00% of the time. (3 out of 30)
# 30: promoted 0.00% of the time. (0 out of 12)
# 31: promoted 0.00% of the time. (0 out of 20)
# 32: promoted 20.00% of the time. (2 out of 10)
# 33: promoted 0.00% of the time. (0 out of 9)
# 34: promoted 25.00% of the time. (1 out of 4)
# 37: promoted 0.00% of the time. (0 out of 1)
# None
# ====================================================================================================
# KPIS_MET>80% :
# 0: promoted 3.96% of the time. (1406 out of 35517)
# 1: promoted 16.91% of the time. (3262 out of 19291)
# None
# ====================================================================================================
# AWARDS_WON? :
# 0: promoted 7.67% of the time. (4109 out of 53538)
# 1: promoted 44.02% of the time. (559 out of 1270)
# None
# ====================================================================================================

# %%
#Retruns histogram of each attribute for bottom 10% of songs, 20-30%. 70-80%, and top 10% of songs
def histogram(df, att):
  width = len(df['att'].unique())
  fig, axes = plt.subplots(2, width)
  c = ['r', 'g', 'b', 'y']
  gen = ['m', 'f']
  for i in range(width):
    df[df['gender'] == q[i]][att].plot(kind = 'hist', ax = axes[i], title = f'{q[i].title()} ({att})', figsize = (8,8))

  fig.tight_layout()

# %%
df['department'].unique()
# Out:
# array(['Sales & Marketing', 'Operations', 'Technology', 'Analytics',
#        'R&D', 'Procurement', 'Finance', 'HR', 'Legal'], dtype=object)

# %%
fig, axes = plt.subplots(2, 1)
male_df[male_df['department'] == 'Analytics']['is_promoted'].plot(kind = 'hist', title = 'Analytics', ax = axes[0], figsize = (8,8))
female_df[female_df['department'] == 'Analytics']['is_promoted'].plot(kind = 'hist', title = 'Analytics_female', ax = axes[1], figsize = (8,8))

fig.tight_layout()

# %%
df.groupby('department').hist(column = 'is_promoted');

# %%
category_no_gender = ['department', 'region', 'education', 'recruitment_channel',
       'no_of_trainings','age', 'previous_year_rating', 'length_of_service',
       'KPIs_met>80%', 'awards_won?']

for col in category_no_gender:
  print(col.upper(),":")
  print(promo_by_group_gender(col))
  print("-"*150)
# Out:
# DEPARTMENT :
# Analytics Males:  were promoted 9.30% of the time. (450 out of 4839)
# Analytics Females: department were promoted 12.09% of the time. (62 out of 513)
# ====================================================================================================
# Finance Males:  were promoted 8.14% of the time. (151 out of 1855)
# Finance Females: department were promoted 8.08% of the time. (55 out of 681)
# ====================================================================================================
# HR Males:  were promoted 5.52% of the time. (78 out of 1412)
# HR Females: department were promoted 5.77% of the time. (58 out of 1006)
# ====================================================================================================
# Legal Males:  were promoted 5.28% of the time. (47 out of 890)
# Legal Females: department were promoted 4.03% of the time. (6 out of 149)
# ====================================================================================================
# Operations Males:  were promoted 8.71% of the time. (581 out of 6671)
# Operations Females: department were promoted 9.45% of the time. (442 out of 4677)
# ====================================================================================================
# Procurement Males:  were promoted 7.87% of the time. (303 out of 3851)
# Procurement Females: department were promoted 11.71% of the time. (385 out of 3287)
# ====================================================================================================
# R&D Males:  were promoted 6.69% of the time. (63 out of 942)
# R&D Females: department were promoted 10.53% of the time. (6 out of 57)
# ====================================================================================================
# Sales & Marketing Males:  were promoted 7.58% of the time. (1037 out of 13686)
# Sales & Marketing Females: department were promoted 5.58% of the time. (176 out of 3154)
# ====================================================================================================
# Technology Males:  were promoted 11.29% of the time. (491 out of 4350)
# Technology Females: department were promoted 9.94% of the time. (277 out of 2788)
# ====================================================================================================
# None
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# REGION :
# region_1 Males:  were promoted 10.43% of the time. (48 out of 460)
# region_1 Females: department were promoted 6.67% of the time. (10 out of 150)
# ====================================================================================================
# region_10 Males:  were promoted 8.10% of the time. (40 out of 494)
# region_10 Females: department were promoted 7.14% of the time. (11 out of 154)
# ====================================================================================================
# region_11 Males:  were promoted 4.98% of the time. (51 out of 1024)
# region_11 Females: department were promoted 7.90% of the time. (23 out of 291)
# ====================================================================================================
# region_12 Males:  were promoted 5.07% of the time. (17 out of 335)
# region_12 Females: department were promoted 9.70% of the time. (16 out of 165)
# ====================================================================================================
# region_13 Males:  were promoted 8.77% of the time. (157 out of 1790)
# region_13 Females: department were promoted 8.51% of the time. (73 out of 858)
# ====================================================================================================
# region_14 Males:  were promoted 7.67% of the time. (46 out of 600)
# region_14 Females: department were promoted 7.05% of the time. (16 out of 227)
# ====================================================================================================
# region_15 Males:  were promoted 7.18% of the time. (157 out of 2186)
# region_15 Females: department were promoted 10.45% of the time. (65 out of 622)
# ====================================================================================================
# region_16 Males:  were promoted 7.34% of the time. (71 out of 967)
# region_16 Females: department were promoted 6.22% of the time. (31 out of 498)
# ====================================================================================================
# region_17 Males:  were promoted 12.33% of the time. (53 out of 430)
# region_17 Females: department were promoted 15.30% of the time. (56 out of 366)
# ====================================================================================================
# region_18 Males:  were promoted 0.00% of the time. (0 out of 27)
# region_18 Females: department were promoted 25.00% of the time. (1 out of 4)
# ====================================================================================================
# region_19 Males:  were promoted 5.34% of the time. (38 out of 711)
# region_19 Females: department were promoted 9.20% of the time. (15 out of 163)
# ====================================================================================================
# region_2 Males:  were promoted 7.99% of the time. (599 out of 7497)
# region_2 Females: department were promoted 8.05% of the time. (390 out of 4846)
# ====================================================================================================
# region_20 Males:  were promoted 5.04% of the time. (34 out of 674)
# region_20 Females: department were promoted 8.52% of the time. (15 out of 176)
# ====================================================================================================
# region_21 Males:  were promoted 3.22% of the time. (11 out of 342)
# region_21 Females: department were promoted 10.14% of the time. (7 out of 69)
# ====================================================================================================
# region_22 Males:  were promoted 11.22% of the time. (523 out of 4662)
# region_22 Females: department were promoted 11.95% of the time. (211 out of 1766)
# ====================================================================================================
# region_23 Males:  were promoted 10.99% of the time. (97 out of 883)
# region_23 Females: department were promoted 13.70% of the time. (40 out of 292)
# ====================================================================================================
# region_24 Males:  were promoted 2.87% of the time. (10 out of 348)
# region_24 Females: department were promoted 5.00% of the time. (8 out of 160)
# ====================================================================================================
# region_25 Males:  were promoted 13.26% of the time. (89 out of 671)
# region_25 Females: department were promoted 9.46% of the time. (14 out of 148)
# ====================================================================================================
# region_26 Males:  were promoted 6.28% of the time. (106 out of 1687)
# region_26 Females: department were promoted 6.46% of the time. (37 out of 573)
# ====================================================================================================
# region_27 Males:  were promoted 7.93% of the time. (96 out of 1211)
# region_27 Females: department were promoted 7.81% of the time. (35 out of 448)
# ====================================================================================================
# region_28 Males:  were promoted 13.36% of the time. (141 out of 1055)
# region_28 Females: department were promoted 4.94% of the time. (13 out of 263)
# ====================================================================================================
# region_29 Males:  were promoted 4.11% of the time. (33 out of 802)
# region_29 Females: department were promoted 5.21% of the time. (10 out of 192)
# ====================================================================================================
# region_3 Males:  were promoted 9.83% of the time. (29 out of 295)
# region_3 Females: department were promoted 15.69% of the time. (8 out of 51)
# ====================================================================================================
# region_30 Males:  were promoted 8.09% of the time. (38 out of 470)
# region_30 Females: department were promoted 11.23% of the time. (21 out of 187)
# ====================================================================================================
# region_31 Males:  were promoted 5.45% of the time. (78 out of 1430)
# region_31 Females: department were promoted 6.34% of the time. (32 out of 505)
# ====================================================================================================
# region_32 Males:  were promoted 3.98% of the time. (28 out of 703)
# region_32 Females: department were promoted 4.96% of the time. (12 out of 242)
# ====================================================================================================
# region_33 Males:  were promoted 4.02% of the time. (9 out of 224)
# region_33 Females: department were promoted 2.22% of the time. (1 out of 45)
# ====================================================================================================
# region_34 Males:  were promoted 1.83% of the time. (5 out of 273)
# region_34 Females: department were promoted 15.79% of the time. (3 out of 19)
# ====================================================================================================
# region_4 Males:  were promoted 14.03% of the time. (170 out of 1212)
# region_4 Females: department were promoted 15.48% of the time. (76 out of 491)
# ====================================================================================================
# region_5 Males:  were promoted 4.31% of the time. (23 out of 534)
# region_5 Females: department were promoted 5.17% of the time. (12 out of 232)
# ====================================================================================================
# region_6 Males:  were promoted 5.17% of the time. (21 out of 406)
# region_6 Females: department were promoted 3.87% of the time. (11 out of 284)
# ====================================================================================================
# region_7 Males:  were promoted 10.52% of the time. (343 out of 3262)
# region_7 Females: department were promoted 10.94% of the time. (173 out of 1581)
# ====================================================================================================
# region_8 Males:  were promoted 7.26% of the time. (32 out of 441)
# region_8 Females: department were promoted 9.81% of the time. (21 out of 214)
# ====================================================================================================
# region_9 Males:  were promoted 2.05% of the time. (8 out of 390)
# region_9 Females: department were promoted 0.00% of the time. (0 out of 30)
# ====================================================================================================
# None
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# EDUCATION :
# Bachelor's Males:  were promoted 8.05% of the time. (2078 out of 25815)
# Bachelor's Females: department were promoted 8.57% of the time. (930 out of 10854)
# ====================================================================================================
# Below Secondary Males:  were promoted 8.91% of the time. (46 out of 516)
# Below Secondary Females: department were promoted 7.27% of the time. (21 out of 289)
# ====================================================================================================
# Master's & above Males:  were promoted 9.55% of the time. (969 out of 10147)
# Master's & above Females: department were promoted 10.51% of the time. (502 out of 4778)
# ====================================================================================================
# Unknown Males:  were promoted 5.35% of the time. (108 out of 2018)
# Unknown Females: department were promoted 3.58% of the time. (14 out of 391)
# ====================================================================================================
# None
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# RECRUITMENT_CHANNEL :
# other Males:  were promoted 8.22% of the time. (1751 out of 21291)
# other Females: department were promoted 8.79% of the time. (805 out of 9155)
# ====================================================================================================
# referred Males:  were promoted 11.23% of the time. (93 out of 828)
# referred Females: department were promoted 14.33% of the time. (45 out of 314)
# ====================================================================================================
# sourcing Males:  were promoted 8.29% of the time. (1357 out of 16377)
# sourcing Females: department were promoted 9.02% of the time. (617 out of 6843)
# ====================================================================================================
# None
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# NO_OF_TRAININGS :
# 1 Males:  were promoted 8.65% of the time. (2624 out of 30344)
# 1 Females: department were promoted 9.16% of the time. (1286 out of 14034)
# ====================================================================================================
# 2 Males:  were promoted 7.50% of the time. (460 out of 6136)
# 2 Females: department were promoted 7.83% of the time. (145 out of 1851)
# ====================================================================================================
# 3 Males:  were promoted 6.54% of the time. (94 out of 1438)
# 3 Females: department were promoted 8.28% of the time. (28 out of 338)
# ====================================================================================================
# 4 Males:  were promoted 4.48% of the time. (18 out of 402)
# 4 Females: department were promoted 12.12% of the time. (8 out of 66)
# ====================================================================================================
# 5 Males:  were promoted 2.61% of the time. (3 out of 115)
# 5 Females: department were promoted 0.00% of the time. (0 out of 13)
# ====================================================================================================
# 6 Males:  were promoted 5.00% of the time. (2 out of 40)
# 6 Females: department were promoted 0.00% of the time. (0 out of 4)
# ====================================================================================================
# 7 Males:  were promoted 0.00% of the time. (0 out of 8)
# 7 Females: department were promoted 0.00% of the time. (0 out of 4)
# ====================================================================================================
# 8 Males:  were promoted 0.00% of the time. (0 out of 4)
# 8 Females: department were promoted 0.00% of the time. (0 out of 1)
# ====================================================================================================
# There are no females in this category
# None
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# AGE :
# 20 Males:  were promoted 2.33% of the time. (2 out of 86)
# 20 Females: department were promoted 7.41% of the time. (2 out of 27)
# ====================================================================================================
# 21 Males:  were promoted 5.88% of the time. (4 out of 68)
# 21 Females: department were promoted 3.33% of the time. (1 out of 30)
# ====================================================================================================
# 22 Males:  were promoted 10.12% of the time. (17 out of 168)
# 22 Females: department were promoted 1.59% of the time. (1 out of 63)
# ====================================================================================================
# 23 Males:  were promoted 8.48% of the time. (28 out of 330)
# 23 Females: department were promoted 6.12% of the time. (6 out of 98)
# ====================================================================================================
# 24 Males:  were promoted 7.54% of the time. (46 out of 610)
# 24 Females: department were promoted 10.21% of the time. (24 out of 235)
# ====================================================================================================
# 25 Males:  were promoted 6.06% of the time. (57 out of 940)
# 25 Females: department were promoted 3.34% of the time. (12 out of 359)
# ====================================================================================================
# 26 Males:  were promoted 8.17% of the time. (122 out of 1493)
# 26 Females: department were promoted 7.23% of the time. (41 out of 567)
# ====================================================================================================
# 27 Males:  were promoted 9.42% of the time. (193 out of 2048)
# 27 Females: department were promoted 8.73% of the time. (68 out of 779)
# ====================================================================================================
# 28 Males:  were promoted 9.98% of the time. (222 out of 2225)
# 28 Females: department were promoted 9.33% of the time. (86 out of 922)
# ====================================================================================================
# 29 Males:  were promoted 8.95% of the time. (214 out of 2392)
# 29 Females: department were promoted 7.90% of the time. (80 out of 1013)
# ====================================================================================================
# 30 Males:  were promoted 8.38% of the time. (217 out of 2591)
# 30 Females: department were promoted 9.96% of the time. (107 out of 1074)
# ====================================================================================================
# 31 Males:  were promoted 8.51% of the time. (208 out of 2444)
# 31 Females: department were promoted 9.36% of the time. (102 out of 1090)
# ====================================================================================================
# 32 Males:  were promoted 8.00% of the time. (190 out of 2376)
# 32 Females: department were promoted 9.24% of the time. (107 out of 1158)
# ====================================================================================================
# 33 Males:  were promoted 9.32% of the time. (205 out of 2199)
# 33 Females: department were promoted 11.28% of the time. (114 out of 1011)
# ====================================================================================================
# 34 Males:  were promoted 8.42% of the time. (179 out of 2125)
# 34 Females: department were promoted 11.25% of the time. (107 out of 951)
# ====================================================================================================
# 35 Males:  were promoted 9.88% of the time. (185 out of 1873)
# 35 Females: department were promoted 11.69% of the time. (98 out of 838)
# ====================================================================================================
# 36 Males:  were promoted 7.32% of the time. (130 out of 1775)
# 36 Females: department were promoted 10.51% of the time. (78 out of 742)
# ====================================================================================================
# 37 Males:  were promoted 8.56% of the time. (130 out of 1519)
# 37 Females: department were promoted 8.36% of the time. (54 out of 646)
# ====================================================================================================
# 38 Males:  were promoted 9.48% of the time. (127 out of 1339)
# 38 Females: department were promoted 9.76% of the time. (57 out of 584)
# ====================================================================================================
# 39 Males:  were promoted 8.87% of the time. (105 out of 1184)
# 39 Females: department were promoted 10.96% of the time. (56 out of 511)
# ====================================================================================================
# 40 Males:  were promoted 7.60% of the time. (92 out of 1211)
# 40 Females: department were promoted 7.74% of the time. (35 out of 452)
# ====================================================================================================
# 41 Males:  were promoted 8.11% of the time. (77 out of 949)
# 41 Females: department were promoted 7.94% of the time. (27 out of 340)
# ====================================================================================================
# 42 Males:  were promoted 8.65% of the time. (70 out of 809)
# 42 Females: department were promoted 6.18% of the time. (21 out of 340)
# ====================================================================================================
# 43 Males:  were promoted 7.53% of the time. (54 out of 717)
# 43 Females: department were promoted 8.36% of the time. (23 out of 275)
# ====================================================================================================
# 44 Males:  were promoted 7.15% of the time. (44 out of 615)
# 44 Females: department were promoted 11.21% of the time. (26 out of 232)
# ====================================================================================================
# 45 Males:  were promoted 6.09% of the time. (34 out of 558)
# 45 Females: department were promoted 6.93% of the time. (14 out of 202)
# ====================================================================================================
# 46 Males:  were promoted 5.26% of the time. (27 out of 513)
# 46 Females: department were promoted 8.70% of the time. (16 out of 184)
# ====================================================================================================
# 47 Males:  were promoted 4.44% of the time. (18 out of 405)
# 47 Females: department were promoted 5.92% of the time. (9 out of 152)
# ====================================================================================================
# 48 Males:  were promoted 8.03% of the time. (33 out of 411)
# 48 Females: department were promoted 7.53% of the time. (11 out of 146)
# ====================================================================================================
# 49 Males:  were promoted 6.83% of the time. (22 out of 322)
# 49 Females: department were promoted 9.24% of the time. (11 out of 119)
# ====================================================================================================
# 50 Males:  were promoted 6.34% of the time. (23 out of 363)
# 50 Females: department were promoted 5.06% of the time. (8 out of 158)
# ====================================================================================================
# 51 Males:  were promoted 7.72% of the time. (20 out of 259)
# 51 Females: department were promoted 10.77% of the time. (14 out of 130)
# ====================================================================================================
# 52 Males:  were promoted 7.76% of the time. (18 out of 232)
# 52 Females: department were promoted 8.40% of the time. (10 out of 119)
# ====================================================================================================
# 53 Males:  were promoted 2.98% of the time. (7 out of 235)
# 53 Females: department were promoted 5.43% of the time. (7 out of 129)
# ====================================================================================================
# 54 Males:  were promoted 8.41% of the time. (19 out of 226)
# 54 Females: department were promoted 5.75% of the time. (5 out of 87)
# ====================================================================================================
# 55 Males:  were promoted 7.18% of the time. (13 out of 181)
# 55 Females: department were promoted 4.42% of the time. (5 out of 113)
# ====================================================================================================
# 56 Males:  were promoted 7.60% of the time. (13 out of 171)
# 56 Females: department were promoted 8.60% of the time. (8 out of 93)
# ====================================================================================================
# 57 Males:  were promoted 3.16% of the time. (5 out of 158)
# 57 Females: department were promoted 0.00% of the time. (0 out of 80)
# ====================================================================================================
# 58 Males:  were promoted 7.03% of the time. (9 out of 128)
# 58 Females: department were promoted 8.24% of the time. (7 out of 85)
# ====================================================================================================
# 59 Males:  were promoted 9.09% of the time. (11 out of 121)
# 59 Females: department were promoted 6.82% of the time. (6 out of 88)
# ====================================================================================================
# 60 Males:  were promoted 8.66% of the time. (11 out of 127)
# 60 Females: department were promoted 3.33% of the time. (3 out of 90)
# ====================================================================================================
# None
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# PREVIOUS_YEAR_RATING :
# 0.0 Males:  were promoted 8.33% of the time. (247 out of 2966)
# 0.0 Females: department were promoted 7.94% of the time. (92 out of 1158)
# ====================================================================================================
# 1.0 Males:  were promoted 1.36% of the time. (62 out of 4562)
# 1.0 Females: department were promoted 1.57% of the time. (26 out of 1661)
# ====================================================================================================
# 2.0 Males:  were promoted 3.70% of the time. (111 out of 3004)
# 2.0 Females: department were promoted 5.73% of the time. (70 out of 1221)
# ====================================================================================================
# 3.0 Males:  were promoted 7.32% of the time. (951 out of 12985)
# 3.0 Females: department were promoted 7.17% of the time. (404 out of 5633)
# ====================================================================================================
# 4.0 Males:  were promoted 8.00% of the time. (547 out of 6840)
# 4.0 Females: department were promoted 7.80% of the time. (237 out of 3037)
# ====================================================================================================
# 5.0 Males:  were promoted 15.76% of the time. (1283 out of 8139)
# 5.0 Females: department were promoted 17.71% of the time. (638 out of 3602)
# ====================================================================================================
# None
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# LENGTH_OF_SERVICE :
# 1 Males:  were promoted 8.40% of the time. (274 out of 3263)
# 1 Females: department were promoted 8.02% of the time. (103 out of 1284)
# ====================================================================================================
# 2 Males:  were promoted 9.04% of the time. (431 out of 4769)
# 2 Females: department were promoted 8.56% of the time. (164 out of 1915)
# ====================================================================================================
# 3 Males:  were promoted 8.54% of the time. (429 out of 5026)
# 3 Females: department were promoted 8.97% of the time. (180 out of 2007)
# ====================================================================================================
# 4 Males:  were promoted 8.28% of the time. (403 out of 4866)
# 4 Females: department were promoted 9.90% of the time. (195 out of 1970)
# ====================================================================================================
# 5 Males:  were promoted 7.50% of the time. (304 out of 4056)
# 5 Females: department were promoted 9.63% of the time. (171 out of 1776)
# ====================================================================================================
# 6 Males:  were promoted 8.25% of the time. (274 out of 3323)
# 6 Females: department were promoted 9.00% of the time. (127 out of 1411)
# ====================================================================================================
# 7 Males:  were promoted 8.06% of the time. (312 out of 3873)
# 7 Females: department were promoted 9.06% of the time. (152 out of 1678)
# ====================================================================================================
# 8 Males:  were promoted 8.78% of the time. (172 out of 1960)
# 8 Females: department were promoted 10.51% of the time. (97 out of 923)
# ====================================================================================================
# 9 Males:  were promoted 8.16% of the time. (144 out of 1764)
# 9 Females: department were promoted 9.83% of the time. (85 out of 865)
# ====================================================================================================
# 10 Males:  were promoted 9.38% of the time. (141 out of 1504)
# 10 Females: department were promoted 9.14% of the time. (63 out of 689)
# ====================================================================================================
# 11 Males:  were promoted 10.24% of the time. (64 out of 625)
# 11 Females: department were promoted 11.00% of the time. (32 out of 291)
# ====================================================================================================
# 12 Males:  were promoted 7.82% of the time. (44 out of 563)
# 12 Females: department were promoted 8.23% of the time. (19 out of 231)
# ====================================================================================================
# 13 Males:  were promoted 8.28% of the time. (39 out of 471)
# 13 Females: department were promoted 6.94% of the time. (15 out of 216)
# ====================================================================================================
# 14 Males:  were promoted 6.39% of the time. (25 out of 391)
# 14 Females: department were promoted 2.53% of the time. (4 out of 158)
# ====================================================================================================
# 15 Males:  were promoted 7.88% of the time. (32 out of 406)
# 15 Females: department were promoted 5.88% of the time. (11 out of 187)
# ====================================================================================================
# 16 Males:  were promoted 7.75% of the time. (31 out of 400)
# 16 Females: department were promoted 6.76% of the time. (10 out of 148)
# ====================================================================================================
# 17 Males:  were promoted 6.77% of the time. (21 out of 310)
# 17 Females: department were promoted 4.10% of the time. (5 out of 122)
# ====================================================================================================
# 18 Males:  were promoted 6.06% of the time. (16 out of 264)
# 18 Females: department were promoted 7.03% of the time. (9 out of 128)
# ====================================================================================================
# 19 Males:  were promoted 8.68% of the time. (21 out of 242)
# 19 Females: department were promoted 12.64% of the time. (11 out of 87)
# ====================================================================================================
# 20 Males:  were promoted 7.32% of the time. (6 out of 82)
# 20 Females: department were promoted 8.70% of the time. (4 out of 46)
# ====================================================================================================
# 21 Males:  were promoted 5.77% of the time. (3 out of 52)
# 21 Females: department were promoted 3.85% of the time. (1 out of 26)
# ====================================================================================================
# 22 Males:  were promoted 10.26% of the time. (4 out of 39)
# 22 Females: department were promoted 9.09% of the time. (2 out of 22)
# ====================================================================================================
# 23 Males:  were promoted 8.70% of the time. (4 out of 46)
# 23 Females: department were promoted 15.79% of the time. (3 out of 19)
# ====================================================================================================
# 24 Males:  were promoted 0.00% of the time. (0 out of 39)
# 24 Females: department were promoted 0.00% of the time. (0 out of 31)
# ====================================================================================================
# 25 Males:  were promoted 3.57% of the time. (1 out of 28)
# 25 Females: department were promoted 4.35% of the time. (1 out of 23)
# ====================================================================================================
# 26 Males:  were promoted 0.00% of the time. (0 out of 31)
# 26 Females: department were promoted 0.00% of the time. (0 out of 10)
# ====================================================================================================
# 27 Males:  were promoted 0.00% of the time. (0 out of 28)
# 27 Females: department were promoted 12.50% of the time. (1 out of 8)
# ====================================================================================================
# 28 Males:  were promoted 5.56% of the time. (1 out of 18)
# 28 Females: department were promoted 8.33% of the time. (1 out of 12)
# ====================================================================================================
# 29 Males:  were promoted 8.70% of the time. (2 out of 23)
# 29 Females: department were promoted 14.29% of the time. (1 out of 7)
# ====================================================================================================
# 30 Males:  were promoted 0.00% of the time. (0 out of 8)
# 30 Females: department were promoted 0.00% of the time. (0 out of 4)
# ====================================================================================================
# 31 Males:  were promoted 0.00% of the time. (0 out of 11)
# 31 Females: department were promoted 0.00% of the time. (0 out of 9)
# ====================================================================================================
# 32 Males:  were promoted 25.00% of the time. (2 out of 8)
# 32 Females: department were promoted 0.00% of the time. (0 out of 2)
# ====================================================================================================
# 33 Males:  were promoted 0.00% of the time. (0 out of 5)
# 33 Females: department were promoted 0.00% of the time. (0 out of 4)
# ====================================================================================================
# 34 Males:  were promoted 100.00% of the time. (1 out of 1)
# 34 Females: department were promoted 0.00% of the time. (0 out of 3)
# ====================================================================================================
# There are no females in this category
# None
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# KPIS_MET>80% :
# 0 Males:  were promoted 3.84% of the time. (975 out of 25394)
# 0 Females: department were promoted 4.26% of the time. (431 out of 10123)
# ====================================================================================================
# 1 Males:  were promoted 16.99% of the time. (2226 out of 13102)
# 1 Females: department were promoted 16.74% of the time. (1036 out of 6189)
# ====================================================================================================
# None
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# AWARDS_WON? :
# 0 Males:  were promoted 7.46% of the time. (2805 out of 37595)
# 0 Females: department were promoted 8.18% of the time. (1304 out of 15943)
# ====================================================================================================
# 1 Males:  were promoted 43.95% of the time. (396 out of 901)
# 1 Females: department were promoted 44.17% of the time. (163 out of 369)
# ====================================================================================================
# None
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#Finding average training score for those who were promoted and not promoted
for department,group in df.groupby('department'):
  promoted_df = group[group['is_promoted'] == 1]
  not_promoted_df = group[group['is_promoted'] == 0]
  training_score_promo = promoted_df['avg_training_score'].mean()
  training_score_not_promo = not_promoted_df['avg_training_score'].mean()
  print(f"Employees in the {department} department who were promoted had an average training score of {training_score_promo}")
  print(f"Employees in the {department} department who were NOT promoted had an average training score of {training_score_not_promo}")
  print('='*125)
# Out:
# Employees in the Analytics department who were promoted had an average training score of 85.833984375
# Employees in the Analytics department who were NOT promoted had an average training score of 84.47272727272727
# =============================================================================================================================
# Employees in the Finance department who were promoted had an average training score of 68.63106796116504
# Employees in the Finance department who were NOT promoted had an average training score of 59.47854077253219
# =============================================================================================================================
# Employees in the HR department who were promoted had an average training score of 57.89705882352941
# Employees in the HR department who were NOT promoted had an average training score of 49.54864154250657
# =============================================================================================================================
# Employees in the Legal department who were promoted had an average training score of 66.41509433962264
# Employees in the Legal department who were NOT promoted had an average training score of 59.51622718052738
# =============================================================================================================================
# Employees in the Operations department who were promoted had an average training score of 67.2218963831867
# Employees in the Operations department who were NOT promoted had an average training score of 59.533559322033895
# =============================================================================================================================
# Employees in the Procurement department who were promoted had an average training score of 75.98982558139535
# Employees in the Procurement department who were NOT promoted had an average training score of 69.49658914728683
# =============================================================================================================================
# Employees in the R&D department who were promoted had an average training score of 85.66666666666667
# Employees in the R&D department who were NOT promoted had an average training score of 84.51720430107527
# =============================================================================================================================
# Employees in the Sales & Marketing department who were promoted had an average training score of 59.93239901071723
# Employees in the Sales & Marketing department who were NOT promoted had an average training score of 49.51103858706086
# =============================================================================================================================
# Employees in the Technology department who were promoted had an average training score of 83.08463541666667
# Employees in the Technology department who were NOT promoted had an average training score of 79.54819466248037
# =============================================================================================================================

# %% [markdown]
# #Looking for possible columns to add

# %%
def split_age(df, col, age):

  for att, group in df.groupby(col):

    older_df = group[group['age'] > age]
    older_total = older_df.shape[0]
    older_promote = older_df[older_df['is_promoted'] == 1].shape[0]
    older_pct = 100*older_promote/older_total

    younger_df = group[group['age'] <= age]
    younger_total = younger_df.shape[0]
    younger_promote = younger_df[younger_df['is_promoted'] == 1].shape[0]
    younger_pct = 100*younger_promote/younger_total

    print(f'People younger than {age+1} with {col} {att} are promoted {younger_pct: .2f}% of the time. ({younger_promote} out of {younger_total})')
    print(f'People older than {age} with {col} {att} are promoted {older_pct: .2f}% of the time. ({older_promote} out of {older_total})')
    #print('-'*150)

# %%
#Doesn't seem to be a huge difference
for age in np.linspace(25,55,5):
  split_age(female_df, 'awards_won?', age)
  print('='*125)
# Out:
# People younger than 26.0 with awards_won? 0 are promoted  5.16% of the time. (41 out of 794)
# People older than 25.0 with awards_won? 0 are promoted  8.34% of the time. (1263 out of 15149)
# People younger than 26.0 with awards_won? 1 are promoted  27.78% of the time. (5 out of 18)
# People older than 25.0 with awards_won? 1 are promoted  45.01% of the time. (158 out of 351)
# =============================================================================================================================
# People younger than 33.5 with awards_won? 0 are promoted  7.80% of the time. (565 out of 7239)
# People older than 32.5 with awards_won? 0 are promoted  8.49% of the time. (739 out of 8704)
# People younger than 33.5 with awards_won? 1 are promoted  40.91% of the time. (72 out of 176)
# People older than 32.5 with awards_won? 1 are promoted  47.15% of the time. (91 out of 193)
# =============================================================================================================================
# People younger than 41.0 with awards_won? 0 are promoted  8.58% of the time. (1103 out of 12851)
# People older than 40.0 with awards_won? 0 are promoted  6.50% of the time. (201 out of 3092)
# People younger than 41.0 with awards_won? 1 are promoted  44.48% of the time. (133 out of 299)
# People older than 40.0 with awards_won? 1 are promoted  42.86% of the time. (30 out of 70)
# =============================================================================================================================
# People younger than 48.5 with awards_won? 0 are promoted  8.41% of the time. (1222 out of 14533)
# People older than 47.5 with awards_won? 0 are promoted  5.82% of the time. (82 out of 1410)
# People younger than 48.5 with awards_won? 1 are promoted  43.86% of the time. (150 out of 342)
# People older than 47.5 with awards_won? 1 are promoted  48.15% of the time. (13 out of 27)
# =============================================================================================================================
# People younger than 56.0 with awards_won? 0 are promoted  8.27% of the time. (1283 out of 15515)
# People older than 55.0 with awards_won? 0 are promoted  4.91% of the time. (21 out of 428)
# People younger than 56.0 with awards_won? 1 are promoted  44.32% of the time. (160 out of 361)
# People older than 55.0 with awards_won? 1 are promoted  37.50% of the time. (3 out of 8)
# =============================================================================================================================

# %%
#only big difference is older than 55, but not many people there
for age in np.linspace(25,55,5):
  split_age(male_df, 'awards_won?', age)
  print('='*125)
# Out:
# People younger than 26.0 with awards_won? 0 are promoted  6.31% of the time. (136 out of 2157)
# People older than 25.0 with awards_won? 0 are promoted  7.53% of the time. (2669 out of 35438)
# People younger than 26.0 with awards_won? 1 are promoted  40.00% of the time. (18 out of 45)
# People older than 25.0 with awards_won? 1 are promoted  44.16% of the time. (378 out of 856)
# =============================================================================================================================
# People younger than 33.5 with awards_won? 0 are promoted  7.71% of the time. (1337 out of 17343)
# People older than 32.5 with awards_won? 0 are promoted  7.25% of the time. (1468 out of 20252)
# People younger than 33.5 with awards_won? 1 are promoted  42.76% of the time. (183 out of 428)
# People older than 32.5 with awards_won? 1 are promoted  45.03% of the time. (213 out of 473)
# =============================================================================================================================
# People younger than 41.0 with awards_won? 0 are promoted  7.73% of the time. (2338 out of 30241)
# People older than 40.0 with awards_won? 0 are promoted  6.35% of the time. (467 out of 7354)
# People younger than 41.0 with awards_won? 1 are promoted  44.37% of the time. (335 out of 755)
# People older than 40.0 with awards_won? 1 are promoted  41.78% of the time. (61 out of 146)
# =============================================================================================================================
# People younger than 48.5 with awards_won? 0 are promoted  7.56% of the time. (2626 out of 34719)
# People older than 47.5 with awards_won? 0 are promoted  6.22% of the time. (179 out of 2876)
# People younger than 48.5 with awards_won? 1 are promoted  44.01% of the time. (371 out of 843)
# People older than 47.5 with awards_won? 1 are promoted  43.10% of the time. (25 out of 58)
# =============================================================================================================================
# People younger than 56.0 with awards_won? 0 are promoted  7.50% of the time. (2767 out of 36905)
# People older than 55.0 with awards_won? 0 are promoted  5.51% of the time. (38 out of 690)
# People younger than 56.0 with awards_won? 1 are promoted  43.45% of the time. (385 out of 886)
# People older than 55.0 with awards_won? 1 are promoted  73.33% of the time. (11 out of 15)
# =============================================================================================================================

# %%
#Reasonable differenec in terms of percentage at age 45, may be worth adding a column
for age in np.linspace(25,55,4):
  split_age(female_df, 'KPIs_met>80%', age)
  print('='*125)
# Out:
# People younger than 26.0 with KPIs_met>80% 0 are promoted  2.71% of the time. (15 out of 553)
# People older than 25.0 with KPIs_met>80% 0 are promoted  4.35% of the time. (416 out of 9570)
# People younger than 26.0 with KPIs_met>80% 1 are promoted  11.97% of the time. (31 out of 259)
# People older than 25.0 with KPIs_met>80% 1 are promoted  16.95% of the time. (1005 out of 5930)
# =============================================================================================================================
# People younger than 36.0 with KPIs_met>80% 0 are promoted  4.45% of the time. (282 out of 6334)
# People older than 35.0 with KPIs_met>80% 0 are promoted  3.93% of the time. (149 out of 3789)
# People younger than 36.0 with KPIs_met>80% 1 are promoted  17.37% of the time. (674 out of 3881)
# People older than 35.0 with KPIs_met>80% 1 are promoted  15.68% of the time. (362 out of 2308)
# =============================================================================================================================
# People younger than 46.0 with KPIs_met>80% 0 are promoted  4.36% of the time. (391 out of 8962)
# People older than 45.0 with KPIs_met>80% 0 are promoted  3.45% of the time. (40 out of 1161)
# People younger than 46.0 with KPIs_met>80% 1 are promoted  17.14% of the time. (956 out of 5577)
# People older than 45.0 with KPIs_met>80% 1 are promoted  13.07% of the time. (80 out of 612)
# =============================================================================================================================
# People younger than 56.0 with KPIs_met>80% 0 are promoted  4.26% of the time. (419 out of 9838)
# People older than 55.0 with KPIs_met>80% 0 are promoted  4.21% of the time. (12 out of 285)
# People younger than 56.0 with KPIs_met>80% 1 are promoted  16.96% of the time. (1024 out of 6038)
# People older than 55.0 with KPIs_met>80% 1 are promoted  7.95% of the time. (12 out of 151)
# =============================================================================================================================

# %%
for age in np.linspace(25,55,4):
  split_age(male_df, 'KPIs_met>80%', age)
  print('='*125)
# Out:
# People younger than 26.0 with KPIs_met>80% 0 are promoted  3.29% of the time. (50 out of 1521)
# People older than 25.0 with KPIs_met>80% 0 are promoted  3.87% of the time. (925 out of 23873)
# People younger than 26.0 with KPIs_met>80% 1 are promoted  15.27% of the time. (104 out of 681)
# People older than 25.0 with KPIs_met>80% 1 are promoted  17.08% of the time. (2122 out of 12421)
# =============================================================================================================================
# People younger than 36.0 with KPIs_met>80% 0 are promoted  4.06% of the time. (632 out of 15583)
# People older than 35.0 with KPIs_met>80% 0 are promoted  3.50% of the time. (343 out of 9811)
# People younger than 36.0 with KPIs_met>80% 1 are promoted  17.38% of the time. (1457 out of 8385)
# People older than 35.0 with KPIs_met>80% 1 are promoted  16.30% of the time. (769 out of 4717)
# =============================================================================================================================
# People younger than 46.0 with KPIs_met>80% 0 are promoted  3.95% of the time. (895 out of 22639)
# People older than 45.0 with KPIs_met>80% 0 are promoted  2.90% of the time. (80 out of 2755)
# People younger than 46.0 with KPIs_met>80% 1 are promoted  17.13% of the time. (2057 out of 12005)
# People older than 45.0 with KPIs_met>80% 1 are promoted  15.41% of the time. (169 out of 1097)
# =============================================================================================================================
# People younger than 56.0 with KPIs_met>80% 0 are promoted  3.86% of the time. (960 out of 24871)
# People older than 55.0 with KPIs_met>80% 0 are promoted  2.87% of the time. (15 out of 523)
# People younger than 56.0 with KPIs_met>80% 1 are promoted  16.97% of the time. (2192 out of 12920)
# People older than 55.0 with KPIs_met>80% 1 are promoted  18.68% of the time. (34 out of 182)
# =============================================================================================================================

# %% [markdown]
# #Model Building Preperation

# %%
from sklearn.model_selection import train_test_split

# %%
female_df = df[df['gender']=='f']
male_df = df[df['gender']=='m']

female_train_df, female_test_df = train_test_split(female_df, test_size=0.3, random_state=0)
male_train_df, male_test_df = train_test_split(male_df, test_size=0.3, random_state=0)

# %%
female_feat_cols = ['department_num', 'KPIs_met>80%', 'avg_training_score']
male_feat_cols = ['department_num', 'awards_won?', 'avg_training_score']
target_col = 'is_promoted'

female_X_train = female_train_df[female_feat_cols]
female_y_train = female_train_df[target_col]

male_X_train = male_train_df[male_feat_cols]
male_y_train = male_train_df[target_col]

female_X_test = female_test_df[female_feat_cols]
female_y_test = female_test_df[target_col]

male_X_test = male_test_df[male_feat_cols]
male_y_test = male_test_df[target_col]

# %% [markdown]
# ##Taking out KPIs_met>80%

# %%
met_KPI_female_train_df, met_KPI_female_test_df = train_test_split(met_KPI_female_df, test_size=0.3, random_state=0)
met_KPI_male_train_df, met_KPI_male_test_df = train_test_split(met_KPI_male_df, test_size=0.3, random_state=0)

no_met_KPI_female_train_df, no_met_KPI_female_test_df = train_test_split(no_met_KPI_female_df, test_size=0.3, random_state=0)
no_met_KPI_male_train_df, no_met_KPI_male_test_df = train_test_split(no_met_KPI_male_df, test_size=0.3, random_state=0)

# %%
no_met_KPI_female_feat_cols = ['no_of_trainings', 'age', 'previous_year_rating', 'length_of_service', 'awards_won?', 'avg_training_score', 'is_promoted',
       'starting_age', 'total_training_score', 'department_num', 'region_num',
       'education_num', 'recruitment_channel_num', 'age_rating', 'age_KPI']
no_met_KPI_male_feat_cols = ['department_num', 'avg_training_score']

met_KPI_female_feat_cols = ['no_of_trainings', 'age', 'previous_year_rating', 'length_of_service', 'awards_won?', 'avg_training_score', 'is_promoted',
       'starting_age', 'total_training_score', 'department_num', 'region_num',
       'education_num', 'recruitment_channel_num', 'age_rating', 'age_KPI']
met_KPI_male_feat_cols = ['department_num', 'no_of_trainings', 'awards_won?', 'avg_training_score']

# %%
no_met_KPI_female_X_train = no_met_KPI_female_train_df[no_met_KPI_female_feat_cols]
no_met_KPI_female_y_train = no_met_KPI_female_train_df[target_col]

no_met_KPI_male_X_train = no_met_KPI_male_train_df[no_met_KPI_male_feat_cols]
no_met_KPI_male_y_train = no_met_KPI_male_train_df[target_col]

no_met_KPI_female_X_test = no_met_KPI_female_test_df[no_met_KPI_female_feat_cols]
no_met_KPI_female_y_test = no_met_KPI_female_test_df[target_col]

no_met_KPI_male_X_test = no_met_KPI_male_test_df[no_met_KPI_male_feat_cols]
no_met_KPI_male_y_test = no_met_KPI_male_test_df[target_col]

# %%
met_KPI_female_X_train = met_KPI_female_train_df[met_KPI_female_feat_cols]
met_KPI_female_y_train = met_KPI_female_train_df[target_col]

met_KPI_male_X_train = met_KPI_male_train_df[met_KPI_male_feat_cols]
met_KPI_male_y_train = met_KPI_male_train_df[target_col]

met_KPI_female_X_test = met_KPI_female_test_df[met_KPI_female_feat_cols]
met_KPI_female_y_test = met_KPI_female_test_df[target_col]

met_KPI_male_X_test = met_KPI_male_test_df[met_KPI_male_feat_cols]
met_KPI_male_y_test = met_KPI_male_test_df[target_col]

# %% [markdown]
# #Undersampling

# %%
# Get only the customers who did not get promoted
female_train_no_df = female_train_df[female_train_df['is_promoted'] == 0]
# Then select of them to match the "1" is_promoted employees
female_train_no_df = female_train_no_df.sample(1043)

# Also grab the promoted employees
female_train_yes_df = female_train_df[female_train_df['is_promoted'] == 1]

# And now stick both DataFrames together to make a new undersampled training set
female_train_under_df = pd.concat([female_train_no_df, female_train_yes_df])

# %%
# Get only the customers who did not get promoted
male_train_no_df = male_train_df[male_train_df['is_promoted'] == 0]
# Then select of them to match the "1" is_promoted employees
male_train_no_df = male_train_no_df.sample(2199)

# Also grab the promoted employees
male_train_yes_df = male_train_df[male_train_df['is_promoted'] == 1]

# And now stick both DataFrames together to make a new undersampled training set
male_train_under_df = pd.concat([male_train_no_df, male_train_yes_df])

# %%
female_feat_cols_under = ['department_num','recruitment_channel_num','previous_year_rating','KPIs_met>80%','awards_won?','avg_training_score']
male_feat_cols_under = ['department_num', 'KPIs_met>80%', 'awards_won?', 'avg_training_score']

# %%
female_X_train_under = female_train_under_df[female_feat_cols_under]
female_y_train_under = female_train_under_df[target_col]

female_X_test_under = female_test_df[female_feat_cols_under]

# %%
male_X_train_under = male_train_under_df[male_feat_cols_under]
male_y_train_under = male_train_under_df[target_col]

male_X_test_under = male_test_df[male_feat_cols_under]

# %% [markdown]
# #Oversampling

# %%
female_train_yes_df = female_train_df[female_train_df['is_promoted'] == 1]
female_train_yes_df = female_train_yes_df.sample(10375, replace=True)

female_train_no_df = female_train_df[female_train_df['is_promoted'] == 0]

# And now stick both DataFrames together to make a new oversampled training set
female_train_over_df = pd.concat([female_train_no_df, female_train_yes_df])

# %%
male_train_yes_df = male_train_df[male_train_df['is_promoted'] == 1]
male_train_yes_df = male_train_yes_df.sample(24748, replace=True)

male_train_no_df = male_train_df[male_train_df['is_promoted'] == 0]

# And now stick both DataFrames together to make a new oversampled training set
male_train_over_df = pd.concat([male_train_no_df, male_train_yes_df])

# %%
female_feat_cols_over = ['department_num',  'no_of_trainings',  'KPIs_met>80%',  'awards_won?',  'avg_training_score']
male_feat_cols_over = ['department_num',  'education_num',  'KPIs_met>80%',  'awards_won?',  'avg_training_score']

# %%
female_X_train_over = female_train_over_df[female_feat_cols_over]
female_y_train_over = female_train_over_df[target_col]

female_X_test_over = female_test_df[female_feat_cols_over]

# %%
male_X_train_over = male_train_over_df[male_feat_cols_over]
male_y_train_over = male_train_over_df[target_col]

male_X_test_over = male_test_df[male_feat_cols_over]

# %% [markdown]
# #KNN Model

# %%
# returns [maximum accuracy in range, the number of neighbors for that max accuracy]
def knn_max_acc(start, n, X_train, y_train, X_test, y_test):

  acc_list = []

  max_neighbors = n

  for N in range(start, max_neighbors+1):
    knn = KNeighborsClassifier(n_neighbors=N, weights= 'distance')
    knn.fit(X_train, y_train)
    test_pred = knn.predict(X_test)

    acc = f1_score(y_test, test_pred)
    acc_list.append([acc,N])
  
  return max(acc_list)

# %%
def powerset(s):
  x = len(s)
  ps = []
  for i in range(1 << x):
       ps.append([s[j] for j in range(x) if (i & (1 << j))])
  
  return ps[1:]

# %%
#Returns best columns for KNN Classifier based on f1 score
all_cols = ['department_num', 'region_num', 'education_num', 'recruitment_channel_num',
       'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service',
       'KPIs_met>80%', 'awards_won?', 'avg_training_score',
       'starting_age', 'total_training_score']

def best_features(train_df, test_df, n=10):
  best_cols = None
  best_f1 = 0
  knn_class = KNeighborsClassifier(n_neighbors = n, weights='distance')
  for cols in powerset(all_cols):
      knn_class.fit(train_df[cols], train_df['is_promoted'])
      X_test = test_df[cols]
      y_test = test_df['is_promoted']
      test_pred = knn_class.predict(X_test)
      if f1_score(y_test, test_pred) > best_f1:
          best_f1 = f1_score(y_test, test_pred)
          best_cols = cols
  return best_cols, best_f1

# %%
#[0.45309734513274336, 8]
knn_max_acc(1, 250, female_X_train, female_y_train, female_X_test, female_y_test)
# Out:
# [0.4587813620071684, 99]

# %%
#[0.514450867052023, 5]
knn_max_acc(1, 250, male_X_train, male_y_train, male_X_test, male_y_test)
# Out:
# [0.514450867052023, 5]

# %%
#[0.36073932441045253, 18]
knn_max_acc(1, 100, female_X_train_under, female_y_train_under, female_X_test_under, female_y_test)
# Out:
# [0.36073932441045253, 18]

# %%
#[0.412258064516129, 4]
knn_max_acc(1, 100, male_X_train_under, male_y_train_under, male_X_test_under, male_y_test)
# Out:
# [0.3921916592724046, 2]

# %%
#[0.40752351097178685, 6]
knn_max_acc(1, 100, female_X_train_over, female_y_train_over, female_X_test_over, female_y_test)
# Out:
# [0.40752351097178685, 6]

# %%
#[0.4102776626605884, 2]
knn_max_acc(1, 100, male_X_train_over, male_y_train_over, male_X_test_over, male_y_test)
# Out:
# [0.39329374781697524, 2]

# %%
#(['department_num', 'KPIs_met>80%', 'avg_training_score'], 0.4522968197879858) for weights = 'uniform'
best_features(female_train_df,female_test_df)

# %%
#(['department_num', 'awards_won?', 'avg_training_score'], 0.4817843866171004)
best_features(male_train_df,male_test_df)

# %%
#(['department_num', 'KPIs_met>80%', 'awards_won?', 'avg_training_score'],0.3996554694229113)
best_features(male_train_under_df, male_test_df)

# %%
#(['department_num','recruitment_channel_num','previous_year_rating','KPIs_met>80%','awards_won?','avg_training_score'],0.3641379310344827)
best_features(female_train_under_df, female_test_df)

# %%
#(['department_num',  'education_num',  'KPIs_met>80%',  'awards_won?',  'avg_training_score'], 0.4019543973941368)
best_features(male_train_over_df, male_test_df)

# %%
#(['department_num',  'no_of_trainings',  'KPIs_met>80%',  'awards_won?',  'avg_training_score'], 0.3710564399421129)
best_features(female_train_over_df, male_test_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-262d4002af6a> in <module>()
#       1 #(['department_num',  'no_of_trainings',  'KPIs_met>80%',  'awards_won?',  'avg_training_score'], 0.3710564399421129)
# ----> 2 best_features(female_train_over_df, male_test_df)
#
# NameError: name 'best_features' is not defined

# %% [markdown]
# ##No KPI model

# %%
knn_max_acc(1, 100, no_met_KPI_female_X_train, no_met_KPI_female_y_train, no_met_KPI_female_X_test, no_met_KPI_female_y_test)
# Out:
# [0.5263157894736842, 3]

# %%
#(['department_num', 'no_of_trainings', 'awards_won?', 'avg_training_score'],
# 0.2888086642599278)
best_features(met_KPI_male_train_df, met_KPI_male_test_df)
# Out:
# (['department_num', 'no_of_trainings', 'awards_won?', 'avg_training_score'],
#  0.2888086642599278)

# %%
met_KPI_male_df['is_promoted'].value_counts()
# Out:
# 0    10876
# 1     2226
# Name: is_promoted, dtype: int64

# %%
#(['department_num', 'avg_training_score'], 0.8260038240917783)
best_features(no_met_KPI_male_train_df, no_met_KPI_male_test_df)
# Out:
# (['department_num', 'avg_training_score'], 0.8260038240917783)

# %%
#(['department_num',
#  'region_num',
#  'previous_year_rating',
#  'avg_training_score'],
# 0.2687224669603524)
best_features(met_KPI_female_train_df, met_KPI_male_test_df)
# Out:
# (['department_num',
#   'region_num',
#   'previous_year_rating',
#   'avg_training_score'],
#  0.2687224669603524)

# %%
#(['department_num', 'avg_training_score'], 0.7894736842105262)
best_features(no_met_KPI_female_train_df, no_met_KPI_male_test_df)
# Out:
# (['department_num', 'avg_training_score'], 0.7894736842105262)

# %% [markdown]
# #Best Model
#   - best model seems to be the original data. Let's look closer at this one

# %%
knn_female = KNeighborsClassifier(n_neighbors = 8)
knn_male = KNeighborsClassifier(n_neighbors= 3)

# %% [markdown]
# ##female

# %%
knn_female.fit(female_X_train, female_y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=8, p=2,
#                      weights='uniform')

# %%
female_preds = knn_female.predict(female_X_test)

# %%
print(plot_confusion_matrix(knn_female,female_X_test,female_y_test, normalize = 'true'))
# Out:
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fc351357c88>

# %%
female_df['is_promoted'].value_counts(normalize=True)
# Out:
# 0    0.910066
# 1    0.089934
# Name: is_promoted, dtype: float64

# %%
accuracy_score(female_y_test, female_preds)
# Out:
# 0.9368614630159379

# %%
accuracy_female_df = female_X_test.copy()
accuracy_female_df['actual'] = female_y_test
accuracy_female_df['pred'] = female_preds
accuracy_female_df['correct'] = accuracy_female_df['actual'] == accuracy_female_df['pred']

# %% [markdown]
# ##male

# %%
knn_male.fit(male_X_train, male_y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
male_preds = knn_male.predict(male_X_test)

# %%
print(plot_confusion_matrix(knn_male,male_X_test,male_y_test, normalize = 'true'))
# Out:
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7fc3511c5748>

# %%
male_df['is_promoted'].value_counts(normalize=True)
# Out:
# 0    0.916849
# 1    0.083151
# Name: is_promoted, dtype: float64

# %%
accuracy_score(male_y_test, male_preds)
# Out:
# 0.9409472681617456

# %% [markdown]
# #Checking where the models predicts wrong

# %%
female_X_test.columns
# Out:
# Index(['department_num', 'KPIs_met>80%', 'avg_training_score'], dtype='object')

# %%
check_acc_female_df = female_test_df.copy()

# %%
check_acc_female_df['pred'] = female_preds

# %%
wrong_female_pred_df = check_acc_female_df[check_acc_female_df['is_promoted'] != check_acc_female_df['pred']]

# %%
wrong_female_pred_df
# Out:
#         department     region         education  ... age_rating age_KPI  pred
# 18660   Operations   region_4        Bachelor's  ...          3       4     0
# 4655    Technology  region_23  Master's & above  ...          5       4     0
# 5582    Technology  region_16        Bachelor's  ...          9       4     0
# 14146   Operations  region_22  Master's & above  ...          5       1     0
# 32037   Technology   region_7        Bachelor's  ...         12       4     0
# ...            ...        ...               ...  ...        ...     ...   ...
# 51967   Technology  region_16        Bachelor's  ...          8       4     0
# 43527  Procurement   region_8  Master's & above  ...         12       4     0
# 27452  Procurement   region_2        Bachelor's  ...          7       4     0
# 51756  Procurement  region_31  Master's & above  ...          4       4     0
# 2601   Procurement  region_15        Bachelor's  ...         12       4     0
#
# [309 rows x 22 columns]

# %%
correct_female_pred_df = check_acc_female_df[check_acc_female_df['is_promoted'] == check_acc_female_df['pred']]

# %%
correct_female_pred_df
# Out:
#               department     region   education  ... age_rating age_KPI  pred
# 25796         Operations  region_26  Bachelor's  ...          7       2     0
# 46748            Finance  region_13  Bachelor's  ...          7       2     0
# 52364         Operations  region_22  Bachelor's  ...          7       4     0
# 7471                  HR   region_2  Bachelor's  ...         10       2     0
# 30007         Operations   region_2  Bachelor's  ...         10       4     0
# ...                  ...        ...         ...  ...        ...     ...   ...
# 44421         Operations   region_8  Bachelor's  ...         12       4     0
# 39667         Operations  region_26  Bachelor's  ...          7       4     0
# 48819          Analytics  region_22  Bachelor's  ...          7       4     0
# 4607          Operations   region_2  Bachelor's  ...         12       4     0
# 51382  Sales & Marketing   region_2  Bachelor's  ...          3       3     0
#
# [4585 rows x 22 columns]

# %%
def make_hist(column, incorrect_df, correct_df):
  fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 8))
  ax1 = incorrect_df[column].plot(kind='hist', ax=axes[0])
  ax2 = correct_df[column].plot(kind='hist', ax =axes[1])
  ax1.set_title(f'Incorrect for {column}')
  ax2.set_title(f'Correct for {column}')

# %%
for col in female_X_test.columns:  
  make_hist(col, wrong_female_pred_df,correct_female_pred_df)
